# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('movie_data.csv')

# %%
data.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6       Nathan Greno     Brad Garrett       Donna Murphy
# 7        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 8        David Yates     Alan Rickman   Daniel Radcliffe
# 9        Zack Snyder     Henry Cavill       Lauren Cohan
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action Adventure Fantasy Sci-Fi
# 1        Jack Davenport                           Action Adventure Fantasy
# 2      Stephanie Sigman                          Action Adventure Thriller
# 3  Joseph Gordon-Levitt                                    Action Thriller
# 4               unknown                                        Documentary
# 5          Polly Walker                            Action Adventure Sci-Fi
# 6           M.C. Gainey  Adventure Animation Comedy Family Fantasy Musi...
# 7    Scarlett Johansson                            Action Adventure Sci-Fi
# 8          Rupert Grint                   Adventure Family Fantasy Mystery
# 9        Alan D. Purwin                            Action Adventure Sci-Fi
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
# 5                                        john carter
# 6                                            tangled
# 7                            avengers: age of ultron
# 8             harry potter and the half-blood prince
# 9                 batman v superman: dawn of justice
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...
# 5  Daryl Sabara Samantha Morton Polly Walker Andr...
# 6  Brad Garrett Donna Murphy M.C. Gainey Nathan G...
# 7  Chris Hemsworth Robert Downey Jr. Scarlett Joh...
# 8  Alan Rickman Daniel Radcliffe Rupert Grint Dav...
# 9  Henry Cavill Lauren Cohan Alan D. Purwin Zack ...

# %%
data.shape
# Out:
# (6010, 7)

# %%
data.columns
# Out:
# Index(['director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name',
#        'genres', 'movie_title', 'comb'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
data.movie_title.value_counts(dropna=False).sort_index().plot(kind='barh',figsize=(15,16))
plt.show()

# %%
data = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
data.head(10)
# Out:
#        director_name     actor_1_name       actor_2_name  \
# 0      James Cameron      CCH Pounder   Joel David Moore
# 1     Gore Verbinski      Johnny Depp      Orlando Bloom
# 2         Sam Mendes  Christoph Waltz       Rory Kinnear
# 3  Christopher Nolan        Tom Hardy     Christian Bale
# 4        Doug Walker      Doug Walker         Rob Walker
# 5     Andrew Stanton     Daryl Sabara    Samantha Morton
# 6       Nathan Greno     Brad Garrett       Donna Murphy
# 7        Joss Whedon  Chris Hemsworth  Robert Downey Jr.
# 8        David Yates     Alan Rickman   Daniel Radcliffe
# 9        Zack Snyder     Henry Cavill       Lauren Cohan
#
#            actor_3_name                                             genres  \
# 0             Wes Studi                    Action Adventure Fantasy Sci-Fi
# 1        Jack Davenport                           Action Adventure Fantasy
# 2      Stephanie Sigman                          Action Adventure Thriller
# 3  Joseph Gordon-Levitt                                    Action Thriller
# 4               unknown                                        Documentary
# 5          Polly Walker                            Action Adventure Sci-Fi
# 6           M.C. Gainey  Adventure Animation Comedy Family Fantasy Musi...
# 7    Scarlett Johansson                            Action Adventure Sci-Fi
# 8          Rupert Grint                   Adventure Family Fantasy Mystery
# 9        Alan D. Purwin                            Action Adventure Sci-Fi
#
#                                          movie_title
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
# 5                                        john carter
# 6                                            tangled
# 7                            avengers: age of ultron
# 8             harry potter and the half-blood prince
# 9                 batman v superman: dawn of justice

# %%
data['actor_1_name'] = data['actor_1_name'].replace(np.nan, 'unknown')
data['actor_2_name'] = data['actor_2_name'].replace(np.nan, 'unknown')
data['actor_3_name'] = data['actor_3_name'].replace(np.nan, 'unknown')
data['director_name'] = data['director_name'].replace(np.nan, 'unknown')

# %%
data
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6005    Joseph Kosinski       Tom Cruise      Miles Teller
# 6006      Joel Crawford     Nicolas Cage        Emma Stone
# 6007        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6008       Ridley Scott       Matt Damon       Adam Driver
# 6009    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6005     Jennifer Connelly                     Action Drama
# 6006         Ryan Reynolds       Animation Adventure Family
# 6007         Marlon Wayans                      Music Drama
# 6008           Jodie Comer                            Drama
# 6009       Neil Sandilands                    Drama Western
#
#                                             movie_title
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6005                                  top gun: maverick
# 6006                                       the croods 2
# 6007                                            respect
# 6008                                      the last duel
# 6009                                  news of the world
#
# [6010 rows x 6 columns]

# %%
data['genres'] = data['genres'].str.replace('|', ' ')
# Out:
# C:\Users\karne\AppData\Local\Temp\ipykernel_23912\3923011829.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['genres'] = data['genres'].str.replace('|', ' ')

# %%
data
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6005    Joseph Kosinski       Tom Cruise      Miles Teller
# 6006      Joel Crawford     Nicolas Cage        Emma Stone
# 6007        Liesl Tommy  Jennifer Hudson   Forest Whitaker
# 6008       Ridley Scott       Matt Damon       Adam Driver
# 6009    Paul Greengrass        Tom Hanks     Helena Zengel
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6005     Jennifer Connelly                     Action Drama
# 6006         Ryan Reynolds       Animation Adventure Family
# 6007         Marlon Wayans                      Music Drama
# 6008           Jodie Comer                            Drama
# 6009       Neil Sandilands                    Drama Western
#
#                                             movie_title
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6005                                  top gun: maverick
# 6006                                       the croods 2
# 6007                                            respect
# 6008                                      the last duel
# 6009                                  news of the world
#
# [6010 rows x 6 columns]

# %%
data['movie_title'] = data['movie_title'].str.lower()

# %%
# null terminating char at the end
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's end"

# %%
# removing the null terminating char at the end
data['movie_title'] = data['movie_title'].apply(lambda x : x[:-1])

# %%
data['movie_title'][1]
# Out:
# "pirates of the caribbean: at world's en"

# %%
data.to_csv('data.csv',index=False)
